# %% [markdown]
# # <h1><center>Bend Workout Set-up</center></h1>

# %% [markdown]
# ### Squat Rack

# %% [markdown]
# ![Squat Rack](data:image/jpeg;base64,...)

# %% [markdown]
# * Amenities
#     1. Squat Rack with safety bars
#     1. Pull up bar
#     1. Lat Pull down machine
#     1. Racks for weights
#
# Squat Rack can be found here at this link: [Squat Rack](https://www.ritfitsports.com/products/ritfit-1000lbs-power-cage?variant=32654149287987&currency=USD&utm_medium=product_sync&utm_source=google&utm_content=sag_organic&utm_campaign=sag_organic&utm_campaign=gs-2019-12-03&utm_source=google&utm_medium=smart_campaign&gclid=Cj0KCQiAoNWOBhCwARIsAAiHnEiOUrzoeIF2QTl3yFQPCaoRp3FEeUkcWM4LoTWT4tXdVPxhm6e7xmUaAgj1EALw_wcB)
#
# Price: $750

# %% [markdown]
# ### Barbell

# %% [markdown]
# ![Barbell](data:image/jpeg;base64,...)

# %% [markdown]
# * Benefits
#     1. One of the cheaper on the market
#     1. 1500 lb capacity
#     1. Official olympic lifting bar
#     1. Easy to clean chalk if used
#
# Barbell can be found at this link: [Black Hawk Barbell](https://www.amazon.com/dp/B07Z9Q1JDR?tag=shgbudgetbar-20&th=1)
#
# Price: $ 189

# %% [markdown]
# ### Bumper plates and Clips

# %% [markdown]
# ![Weights](data:image/jpeg;base64,...)
#
# ![collars](https://www.verywellfit.com/thmb/SAb5tOjWnuXP5NElnFcl2SWCyO0=/fit-in/280x230/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/CloutFitnessQuickReleasePairofLocking2-inchOlympicSizeBarbellClampCollar-6c5a7cba7f134b748111596a15c43df0.jpg)

# %% [markdown]
# * Benefits
#     1. Cheap compared to market
#     1. 250 lbs of weight
#     1. Won't damage floor if dropped
#
# Weights can be found at: [Bumper Plates](https://repfitness.com/products/black-bumper-plate-sets)
#
# Price for weights: $ 520
#
# Price for collars: $ 17
#
# # <h1><center>Total Pricing</center></h1>
#
# ### Total Price: $ 1476
